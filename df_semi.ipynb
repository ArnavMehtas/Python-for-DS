# %% [markdown]
# # DATAFRAME FOR SEMICONDUCTOR SUPPLY CHAIN

# %% [raw]
# FEATURES:
#
# 1. Production Capacity: The total output capacity of the semiconductor manufacturing facility.
#
# 2. Utilization Rates: How efficiently the production capacity is being utilized.
#
# 3. Inventory Levels: Stock levels of finished goods and raw materials.
#
# 4. Lead Times: Time required to fulfill orders from production to delivery.
#
# 5. Order Backlogs: Pending orders yet to be fulfilled.
#
# 6. Customer Contracts: Long-term agreements with customers for supply.
#
# 7. Quality Metrics: Defect rates or quality control measures in production.
#
# 8. Employee Count: Number of workers directly involved in production and operations.
#
# 9. Training Levels: Skill levels and training programs for employees.
#
# 10. Energy Consumption: Amount of energy consumed in production processes.
#
# 11. Raw Material Costs: Costs of materials used in manufacturing.
#
# 12. Transportation Costs: Costs associated with transporting goods to customers.
#
# 13. Labor Turnover Rate: Annual turnover rate of employees
#
# 14. R&D Investment: Investment in research and development for new products or processes.
#
# 15. Marketing and Sales Efforts: Resources allocated to promoting products and expanding market reach.
#
# 16. Customer Feedback: Satisfaction scores or feedback from customers.
#
# 17. Supplier Relationships: Relationships with key suppliers and dependency levels.
#
# 18. Financial Performance: Revenue, profit margins, and cash flow metrics.
#
# 19.Market Share: Percentage of total market captured by the company.
#
# 20. Competitor Actions: Monitoring competitors' product launches, pricing strategies, and market positioning.
#
# 21.Supplier Diversity: Percentage of suppliers from different geographic regions or sectors.
#
# 22. Average Age of Equipment: Average age of machinery and equipment used in manufacturing.

# %%
import pandas as pd

# Sample data for a semiconductor manufacturing company
data = {
    'Production_Capacity': [100000, 95000, 105000],
    'Utilization_Rates': [0.85, 0.78, 0.92],
    'Inventory_Levels': [15000, 12000, 18000],
    'Lead_Times': [5, 4, 6],
    'Order_Backlogs': [2000, 1500, 2500],
    'Customer_Contracts': ['Yes', 'Yes', 'No'],
    'Quality_Metrics': [0.02, 0.015, 0.025],
    'Employee_Count': [500, 450, 550],
    'Training_Levels': ['High', 'Medium', 'High'],
    'Energy_Consumption_kWh': [85000, 80000, 90000],
    'Raw_Material_Costs': [500000, 480000, 520000],
    'Transportation_Costs': [20000, 18000, 22000],
    'Labor_Turnover_Rate': [0.15, 0.12, 0.18],
    'R&D_Investment': [300000, 280000, 320000],
    'Marketing_Sales_Efforts': [200000, 180000, 220000],
    'Customer_Feedback_Score': [8.5, 8.2, 8.8],
    'Supplier_Relationships': ['Stable', 'Moderate', 'Strong'],
    'Financial_Performance': ['Profitable', 'Profitable', 'Profitable'],
    'Market_Share': [15, 14, 16],
    'Competitor_Actions': ['New product launch', 'Price reduction', 'Market expansion'],
    'Supplier_Diversity': [0.25, 0.30, 0.20],
    'Average_Age_of_Equipment': [5, 4, 6]
}

# Creating the DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#    Production_Capacity  Utilization_Rates  Inventory_Levels  Lead_Times  \
# 0               100000               0.85             15000           5
# 1                95000               0.78             12000           4
# 2               105000               0.92             18000           6
#
#    Order_Backlogs Customer_Contracts  Quality_Metrics  Employee_Count  \
# 0            2000                Yes            0.020             500
# 1            1500                Yes            0.015             450
# 2            2500                 No            0.025             550
#
#   Training_Levels  Energy_Consumption_kWh  Raw_Material_Costs  \
# 0            High                   85000              500000
# 1          Medium                   80000              480000
# 2            High                   90000              520000
#
#    Transportation_Costs Environmental_Compliance  R&D_Investment  \
# 0                 20000                      Yes          300000
# ...
